# %%
import os
import pandas as pd
from dotenv import load_dotenv
from services.sheets_client import google_client_authentication

load_dotenv()
# Out:
# True

# %%
spreadsheet_id = os.getenv("SHEET_ID")
google_credentials = os.getenv('GOOGLE_SHEETS_CREDENTIALS')

sheet = google_client_authentication(google_credentials, spreadsheet_id)

# %%
raw_data = sheet.worksheet("Dados Brutos")

v = raw_data.get_all_values()
df = pd.DataFrame(v)

df
# Out:
#                        0                1                  2  \
# 0     ID do Pedido Yampi  Data de Criação  Data de Pagamento
# 1              134546134       14/04/2025         14/04/2025
# 2              134546014       14/04/2025         14/04/2025
# 3              134545763       14/04/2025         14/04/2025
# 4              134545738       14/04/2025
# ...                  ...              ...                ...
# 2194           135176701       25/04/2025         25/04/2025
# 2195           135177779       25/04/2025         25/04/2025
# 2196           135177726       25/04/2025         25/04/2025
# 2197           135177692       25/04/2025         25/04/2025
# 2198           135177138       25/04/2025         25/04/2025
#
#                              3                                  4  \
# 0                      Cliente                              Email
# 1     Cláudio Santos de Moraes  claudiomoraes@apmpriopreto.com.br
# 2     Carlos Donizete Rossetti      transporte.rossetti@gmail.com
# 3                NELSON VARGAS       nelson.vargas@premold.com.br
# 4        Sílvio Gregório viana           123gferromacae@gmail.com
# ...                        ...                                ...
# 2194   Ronaldo Dias Dos Santos                rdo473250@gmail.com
# 2195  José Celso da Costa Neto                 jc.zenon@gmail.com
# 2196            Antônio Divino              waldodivino@gmail.com
# 2197              Luiz esteves          sevetse.itapebi@gmail.com
# 2198       SALETE ROSA BOSCATO            saleteboscato@gmail.com
#
#                                                       5           6  \
# 0                                               Produto  Quantidade
# 1                 6 Frascos - Evo Prost Gotas (VJ CALL)           1
# 2         Compre 3 leve 5 frascos Urocianina Gotas - LH           1
# 3     Compre 2 e leve 3 frascos - Urocianina Gotas - JP           1
# 4         Compre 3 e Leve 5 Frascos INSUFREE Gotas - LH           1
# ...                                                 ...         ...
# 2194  Compre 5 e leve 10 frascos - Urocianina Gotas ...           1
# 2195    Compre 2 e leve 3 frascos - EvoProst Gotas - LG           1
# 2196    Compre 2 e leve 3 frascos - EvoProst Gotas - LG           1
# 2197      Compre 3 e Leve 5 Frascos INSUFREE Gotas - LH           1
# 2198  PROMOÇÃO! Compre 2 e Leve 5 Frascos INSUFREE G...           1
#
#                 7                     8                    9
# 0     Valor Total                Status  Método de Pagamento
# 1             290              Faturado                  Elo
# 2             397              Faturado     American Express
# 3             297         Em transporte                 Visa
# 4           396,9             Cancelado      Boleto Bancário
# ...           ...                   ...                  ...
# 2194          597  Aguardando pagamento      Boleto Bancário
# 2195        296,9  Aguardando pagamento      Boleto Bancário
# 2196       357,71    Pagamento aprovado                 Visa
# 2197        396,9  Aguardando pagamento      Boleto Bancário
# 2198        296,9    Pagamento aprovado                 Visa
#
# [2199 rows x 10 columns]

# %%
raw_data = sheet.worksheet("Pedidos Processados")

v = raw_data.get_all_values()
df = pd.DataFrame(v)

df
# Out:
#                 0               1          2       3              4       5   \
# 0     Data criação  Data pagamento  Pedido ID  Gestor  Tipo de venda  Upsell
# 1       2025-04-14      2025-04-14  134546134      VJ     Callcenter     Não
# 2       2025-04-14      2025-04-14  134546014      LH         Normal     Não
# 3       2025-04-14      2025-04-14  134545763      JP         Normal     Não
# 4       2025-04-14      2025-04-14  134545738      LH         Normal     Não
# ...            ...             ...        ...     ...            ...     ...
# 8671
# 8672
# 8673
# 8674
# 8675
#
#               6                         7                                  8   \
# 0     Order Bump                   Cliente                              Email
# 1            Não  Cláudio Santos de Moraes  claudiomoraes@apmpriopreto.com.br
# 2            Não  Carlos Donizete Rossetti      transporte.rossetti@gmail.com
# 3            Não             NELSON VARGAS       nelson.vargas@premold.com.br
# 4            Não     Sílvio Gregório viana           123gferromacae@gmail.com
# ...          ...                       ...                                ...
# 8671
# 8672
# 8673
# 8674
# 8675
#
#                                                      9                 10  \
# 0                                               Produto         Produto 2
# 1                 6 Frascos - Evo Prost Gotas (VJ CALL)   Evo Prost Gotas
# 2         Compre 3 leve 5 frascos Urocianina Gotas - LH  Urocianina Gotas
# 3     Compre 2 e leve 3 frascos - Urocianina Gotas - JP  Urocianina Gotas
# 4         Compre 3 e Leve 5 Frascos INSUFREE Gotas - LH    Insufree Gotas
# ...                                                 ...               ...
# 8671
# 8672
# 8673
# 8674
# 8675
#
#               11           12                    13                   14 15  \
# 0     Quantidade  Valor Total                Status  Método de Pagamento
# 1              6          290              Faturado                  Elo
# 2              5          397              Faturado     American Express
# 3              3          297         Em transporte                 Visa
# 4              5        396,9  Aguardando pagamento      Boleto Bancário
# ...          ...          ...                   ...                  ... ..
# 8671
# 8672
# 8673
# 8674
# 8675
#
#                         16                 17                         18
# 0     Data do investimento  Gestor que gastou  Investimento dos gestores
# 1               01/02/2025                 LG                     756,97
# 2               03/02/2025                 LG                      12,89
# 3               03/02/2025                 LG                      12,13
# 4               03/02/2025                 LG                      18,63
# ...                    ...                ...                        ...
# 8671            09/04/2025                 JP                      71,30
# 8672            09/04/2025                 JP                     140,19
# 8673            09/04/2025                 JP                      30,93
# 8674            09/04/2025                 JP                      38,33
# 8675            10/04/2025                 JP                     720,23
#
# [8676 rows x 19 columns]
